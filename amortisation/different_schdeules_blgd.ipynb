# %% [markdown]
# # Effect of different schedules on Expected Shortfall
#
# ## Balanced sectoral weighing
#
# ### Parameters
#
# J = 3; N_firms = 1000
#
# c = 0.01
#
# r = 0.12
# N = 12
#
# 5000 Monte Carlo Trials

# %% [markdown]
# ### LGD $\sim$ Beta($\alpha$, $\beta$)

# %%
from ipynb.fs.full.stochastic_lgd import *

# %%
rng = np.random.default_rng(1265883927568217)

N_firms = 1000
J = 3

c = 0.01

T = 1.0

NUM_TRIALS = 2500

kappa = rng.uniform(0.5, 1.5, J)
theta = rng.uniform(0.001, 0.051, J)
sigma_inter = rng.uniform(0.0, 0.2, J)
sigma = np.minimum(np.sqrt(2*kappa*theta), sigma_inter)

idio_factor = rng.uniform(0.01, 0.03, N_firms)

feller = (2 * kappa * theta) / (sigma**2)
print("Feller condition (should be >=1):", feller)

W = generate_portfolio_weights(N_firms, J, "balanced", rng=rng)

delta = c * W

lambda_benchmark = np.array([
    lambda_max_generator(1e-4, theta[j], theta[j],
                         sigma[j], kappa[j])
    for j in range(J)
])


params = {
    'Firms': N_firms,
    'Sectors': J,
    'Global Senstivity Param': c,
    'kappa': kappa,
    'theta': theta,
    'sigma': sigma,
    'delta': delta,
    'lambda_benchmark': lambda_benchmark,
    'idio_factor': idio_factor,
    'W': W,
    'T': T
}
# Out:
# Feller condition (should be >=1): [3.637663 4.700201 5.508869]

# %%
params_df = pd.DataFrame({
    'kappa': kappa,
    'theta': theta,
    'sigma': sigma,
    'lambda_benchmark': lambda_benchmark
}, index=[f'Sector_{j}' for j in range(J)])

print("Parameters per Sector:")
print(params_df)

print("\n\nPortfolio Weights (W):")
W_df = pd.DataFrame(W, columns=[f'Sector_{j}' for j in range(J)], index=pd.Index(range(N_firms), name='Firm'))
print(W_df)
# Out:
# Parameters per Sector:
#             kappa    theta    sigma  lambda_benchmark
# Sector_0 0.694378 0.048318 0.135817          0.259574
# Sector_1 1.121571 0.049001 0.152923          0.229543
# Sector_2 1.408060 0.014160 0.085078          0.076515
#
#
# Portfolio Weights (W):
#       Sector_0  Sector_1  Sector_2
# Firm
# 0     0.333333  0.333333  0.333333
# 1     0.333333  0.333333  0.333333
# 2     0.333333  0.333333  0.333333
# 3     0.333333  0.333333  0.333333
# 4     0.333333  0.333333  0.333333
# ...        ...       ...       ...
# 995   0.333333  0.333333  0.333333
# 996   0.333333  0.333333  0.333333
# 997   0.333333  0.333333  0.333333
# 998   0.333333  0.333333  0.333333
# 999   0.333333  0.333333  0.333333
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## Bullet Loan
# repayment where the outstanding principal is repaid in full at the time of "maturity" (default).

# %%
loan_b = [
    {
        "type": 'bullet',
        "P": 10.0,
        "N": 12,
        "r": 0.12,
    }
    for i in range(N_firms)
]

losses_b = run_simulation(params, loan_b, num_trials=NUM_TRIALS)
metrics_b = compute_metrics(losses_b, alpha=0.95)
metrics_b_df = pd.DataFrame(metrics_b, index=['Bullet'])
print(metrics_b_df)

loss_distribution_plot(losses_b, 'balanced_bullet')
# Out:
#              Mean       Std        VaR         ES  Excess ES  ExcessKurtosis
# Bullet 445.579631 91.506803 603.003102 649.135689  46.132587        0.042834

# %% [markdown]
# ## French amortisation
# repayment scheme where a constant total installment (Principal + Interest) throughout the life of the loan is paid

# %%
loan_f = [
    {
        "type": 'french',
        "P": 10.0,
        "N": 12,
        "r": 0.12,
    }
    for i in range(N_firms)
]

losses_f = run_simulation(params, loan_f, num_trials=NUM_TRIALS)
metrics_f = compute_metrics(losses_f, alpha=0.95)
metrics_f_df = pd.DataFrame(metrics_f, index=['French'])
print(metrics_f_df)

loss_distribution_plot(losses_f, 'balanced_french')
# Out:
#              Mean       Std        VaR         ES  Excess ES  ExcessKurtosis
# French 192.255109 40.060913 260.139480 283.384827  23.245347        0.361069

# %% [markdown]
# ## Linear (Italian) amortisation
# repayment scheme characterised by a constant repayment of principal in each installment.

# %%
loan_l = [
    {
        "type": 'linear',
        "P": 10.0,
        "N": 12,
        "r": 0.12,
    }
    for i in range(N_firms)
]

losses_l = run_simulation(params, loan_l, num_trials=NUM_TRIALS)
metrics_l = compute_metrics(losses_l, alpha=0.95)
metrics_l_df = pd.DataFrame(metrics_l, index=['Linear'])
print(metrics_l_df)

loss_distribution_plot(losses_l, 'balanced_linear')
# Out:
#              Mean       Std        VaR         ES  Excess ES  ExcessKurtosis
# Linear 187.345772 39.074120 253.624228 275.740959  22.116731        0.443822

# %% [markdown]
# ## Negative Amortisation
# repayment scheme where unpaid interest is capitalized, causing the outstanding balance to grow over time.

# %%
loan_n = [
    {
        "type": 'negative_amortisation',
        "P": 10.0,
        "N": 12,
        "r": 0.12,
    }
    for i in range(N_firms)
]

losses_n = run_simulation(params, loan_n, num_trials=NUM_TRIALS)
metrics_n = compute_metrics(losses_n, alpha=0.95)
metrics_n_df = pd.DataFrame(metrics_n, index=['Neg. Amort.'])
print(metrics_n_df)

loss_distribution_plot(losses_n, 'balanced_neg_amort')
# Out:
#                   Mean        Std        VaR         ES  Excess ES  \
# Neg. Amort. 487.980070 101.762598 665.733316 719.655466  53.922150
#
#              ExcessKurtosis
# Neg. Amort.        0.248248

# %%
balancedsectors_df = pd.concat([metrics_b_df, metrics_f_df, metrics_l_df, metrics_n_df])
balancedsectors_df
# Out:
#                   Mean        Std        VaR         ES  Excess ES  \
# Bullet      445.579631  91.506803 603.003102 649.135689  46.132587
# French      192.255109  40.060913 260.139480 283.384827  23.245347
# Linear      187.345772  39.074120 253.624228 275.740959  22.116731
# Neg. Amort. 487.980070 101.762598 665.733316 719.655466  53.922150
#
#              ExcessKurtosis
# Bullet             0.042834
# French             0.361069
# Linear             0.443822
# Neg. Amort.        0.248248

# %% [markdown]
# ## Concentrated sectoral weighing

# %%
rng = np.random.default_rng(1265883927568217)

N_firms = 1000
J = 3

c = 0.01

T = 1.0

NUM_TRIALS = 2500

kappa = rng.uniform(0.5, 1.5, J)
theta = rng.uniform(0.001, 0.051, J)
sigma_inter = rng.uniform(0.0, 0.2, J)
sigma = np.minimum(np.sqrt(2*kappa*theta), sigma_inter)

idio_factor = rng.uniform(0.01, 0.03, N_firms)

feller = (2 * kappa * theta) / (sigma**2)
print("Feller condition (should be >=1):", feller)

W = generate_portfolio_weights(N_firms, J, "concentrated", rng=rng)

delta = c * W

lambda_benchmark = np.array([
    lambda_max_generator(1e-4, theta[j], theta[j],
                         sigma[j], kappa[j])
    for j in range(J)
])


params = {
    'Firms': N_firms,
    'Sectors': J,
    'Global Senstivity Param': c,
    'kappa': kappa,
    'theta': theta,
    'sigma': sigma,
    'delta': delta,
    'lambda_benchmark': lambda_benchmark,
    'idio_factor': idio_factor,
    'W': W,
    'T': T
}
# Out:
# Feller condition (should be >=1): [3.637663 4.700201 5.508869]

# %%
params_df = pd.DataFrame({
    'kappa': kappa,
    'theta': theta,
    'sigma': sigma,
    'lambda_benchmark': lambda_benchmark
}, index=[f'Sector_{j}' for j in range(J)])

print("Parameters per Sector:")
print(params_df)

print("\n\nPortfolio Weights (W):")
W_df = pd.DataFrame(W, columns=[f'Sector_{j}' for j in range(J)], index=pd.Index(range(N_firms), name='Firm'))
print(W_df)
# Out:
# Parameters per Sector:
#             kappa    theta    sigma  lambda_benchmark
# Sector_0 0.694378 0.048318 0.135817          0.259574
# Sector_1 1.121571 0.049001 0.152923          0.229543
# Sector_2 1.408060 0.014160 0.085078          0.076515
#
#
# Portfolio Weights (W):
#       Sector_0  Sector_1  Sector_2
# Firm
# 0     0.700000  0.150000  0.150000
# 1     0.700000  0.150000  0.150000
# 2     0.700000  0.150000  0.150000
# 3     0.700000  0.150000  0.150000
# 4     0.700000  0.150000  0.150000
# ...        ...       ...       ...
# 995   0.700000  0.150000  0.150000
# 996   0.700000  0.150000  0.150000
# 997   0.700000  0.150000  0.150000
# 998   0.700000  0.150000  0.150000
# 999   0.700000  0.150000  0.150000
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## Bullet Loan
# repayment where the outstanding principal is repaid in full at the time of "maturity" (default).

# %%
loan_b = [
    {
        "type": 'bullet',
        "P": 10.0,
        "N": 12,
        "r": 0.12,
    }
    for i in range(N_firms)
]

losses_b = run_simulation(params, loan_b, num_trials=NUM_TRIALS)
metrics_b = compute_metrics(losses_b, alpha=0.95)
metrics_b_df = pd.DataFrame(metrics_b, index=['Bullet'])
print(metrics_b_df)

loss_distribution_plot(losses_b, 'concentrated_bullet')
# Out:
#              Mean        Std         VaR          ES  Excess ES  \
# Bullet 781.366598 178.312980 1094.014513 1181.983486  87.968973
#
#         ExcessKurtosis
# Bullet        0.082623

# %% [markdown]
# ## French amortisation
# repayment scheme where a constant total installment (Principal + Interest) throughout the life of the loan is paid

# %%
loan_f = [
    {
        "type": 'french',
        "P": 10.0,
        "N": 12,
        "r": 0.12,
    }
    for i in range(N_firms)
]

losses_f = run_simulation(params, loan_f, num_trials=NUM_TRIALS)
metrics_f = compute_metrics(losses_f, alpha=0.95)
metrics_f_df = pd.DataFrame(metrics_f, index=['French'])
print(metrics_f_df)

loss_distribution_plot(losses_f, 'concentrated_french')
# Out:
#              Mean       Std        VaR         ES  Excess ES  ExcessKurtosis
# French 272.476942 64.677614 387.691663 423.493493  35.801830        0.430189

# %% [markdown]
# ## Linear (Italian) amortisation
# repayment scheme characterised by a constant repayment of principal in each installment.

# %%
loan_l = [
    {
        "type": 'linear',
        "P": 10.0,
        "N": 12,
        "r": 0.12,
    }
    for i in range(N_firms)
]

losses_l = run_simulation(params, loan_l, num_trials=NUM_TRIALS)
metrics_l = compute_metrics(losses_l, alpha=0.95)
metrics_l_df = pd.DataFrame(metrics_l, index=['Linear'])
print(metrics_l_df)

loss_distribution_plot(losses_l, 'concentrated_linear')
# Out:
#              Mean       Std        VaR         ES  Excess ES  ExcessKurtosis
# Linear 266.874044 63.283383 378.276798 412.823189  34.546391        0.284163

# %%
loan_n = [
    {
        "type": 'negative_amortisation',
        "P": 10.0,
        "N": 12,
        "r": 0.12,
    }
    for i in range(N_firms)
]

losses_n = run_simulation(params, loan_n, num_trials=NUM_TRIALS)
metrics_n = compute_metrics(losses_n, alpha=0.95)
metrics_n_df = pd.DataFrame(metrics_n, index=['Neg. Amort.'])
print(metrics_n_df)

loss_distribution_plot(losses_n, 'concentrated_neg_amort')
# Out:
#                   Mean        Std         VaR          ES  Excess ES  \
# Neg. Amort. 884.657616 208.297478 1254.781786 1350.512504  95.730718
#
#              ExcessKurtosis
# Neg. Amort.       -0.018813

# %%
concentratedsectors_df = pd.concat([metrics_b_df, metrics_f_df, metrics_l_df, metrics_n_df])
concentratedsectors_df
# Out:
#                   Mean        Std         VaR          ES  Excess ES  \
# Bullet      781.366598 178.312980 1094.014513 1181.983486  87.968973
# French      272.476942  64.677614  387.691663  423.493493  35.801830
# Linear      266.874044  63.283383  378.276798  412.823189  34.546391
# Neg. Amort. 884.657616 208.297478 1254.781786 1350.512504  95.730718
#
#              ExcessKurtosis
# Bullet             0.082623
# French             0.430189
# Linear             0.284163
# Neg. Amort.       -0.018813

# %% [markdown]
# ## Random sectoral weighing

# %%
rng = np.random.default_rng(1265883927568217)

N_firms = 1000
J = 3

c = 0.01

T = 1.0

NUM_TRIALS = 2500

kappa = rng.uniform(0.5, 1.5, J)
theta = rng.uniform(0.001, 0.051, J)
sigma_inter = rng.uniform(0.0, 0.2, J)
sigma = np.minimum(np.sqrt(2*kappa*theta), sigma_inter)

idio_factor = rng.uniform(0.01, 0.03, N_firms)

feller = (2 * kappa * theta) / (sigma**2)
print("Feller condition (should be >=1):", feller)

W = generate_portfolio_weights(N_firms, J, "random", rng=rng)

delta = c * W

lambda_benchmark = np.array([
    lambda_max_generator(1e-4, theta[j], theta[j],
                         sigma[j], kappa[j])
    for j in range(J)
])


params = {
    'Firms': N_firms,
    'Sectors': J,
    'Global Senstivity Param': c,
    'kappa': kappa,
    'theta': theta,
    'sigma': sigma,
    'delta': delta,
    'lambda_benchmark': lambda_benchmark,
    'idio_factor': idio_factor,
    'W': W,
    'T': T
}
# Out:
# Feller condition (should be >=1): [3.637663 4.700201 5.508869]

# %%
loan_b = [
    {
        "type": 'bullet',
        "P": 10.0,
        "N": 12,
        "r": 0.12,
    }
    for i in range(N_firms)
]

losses_b = run_simulation(params, loan_b, num_trials=NUM_TRIALS)
metrics_b = compute_metrics(losses_b, alpha=0.95)
metrics_b_df = pd.DataFrame(metrics_b, index=['Bullet'])
print(metrics_b_df)

loss_distribution_plot(losses_b, 'random_bullet')
# Out:
#              Mean       Std        VaR         ES  Excess ES  ExcessKurtosis
# Bullet 447.596965 92.954514 606.459003 657.069784  50.610781        0.236004

# %%
loan_f = [
    {
        "type": 'french',
        "P": 10.0,
        "N": 12,
        "r": 0.12,
    }
    for i in range(N_firms)
]

losses_f = run_simulation(params, loan_f, num_trials=NUM_TRIALS)
metrics_f = compute_metrics(losses_f, alpha=0.95)
metrics_f_df = pd.DataFrame(metrics_f, index=['French'])
print(metrics_f_df)

loss_distribution_plot(losses_f, 'random_french')
# Out:
#              Mean       Std        VaR         ES  Excess ES  ExcessKurtosis
# French 192.493395 41.560070 263.521477 285.859112  22.337635        0.253306

# %%
loan_l = [
    {
        "type": 'linear',
        "P": 10.0,
        "N": 12,
        "r": 0.12,
    }
    for i in range(N_firms)
]

losses_l = run_simulation(params, loan_l, num_trials=NUM_TRIALS)
metrics_l = compute_metrics(losses_l, alpha=0.95)
metrics_l_df = pd.DataFrame(metrics_l, index=['Linear'])
print(metrics_l_df)

loss_distribution_plot(losses_l, 'random_linear')
# Out:
#              Mean       Std        VaR         ES  Excess ES  ExcessKurtosis
# Linear 187.773535 38.991533 256.645885 275.440458  18.794573        0.108394

# %%
loan_n = [
    {
        "type": 'negative_amortisation',
        "P": 10.0,
        "N": 12,
        "r": 0.12,
    }
    for i in range(N_firms)
]

losses_n = run_simulation(params, loan_n, num_trials=NUM_TRIALS)
metrics_n = compute_metrics(losses_n, alpha=0.95)
metrics_n_df = pd.DataFrame(metrics_n, index=['Neg. Amort.'])
print(metrics_n_df)

loss_distribution_plot(losses_n, 'random_neg_amort')
# Out:
#                   Mean        Std        VaR         ES  Excess ES  \
# Neg. Amort. 490.735649 102.750444 669.806880 723.163827  53.356947
#
#              ExcessKurtosis
# Neg. Amort.        0.184273

# %%
randomsectors_df = pd.concat([metrics_b_df, metrics_f_df, metrics_l_df, metrics_n_df])
randomsectors_df
# Out:
#                   Mean        Std        VaR         ES  Excess ES  \
# Bullet      447.596965  92.954514 606.459003 657.069784  50.610781
# French      192.493395  41.560070 263.521477 285.859112  22.337635
# Linear      187.773535  38.991533 256.645885 275.440458  18.794573
# Neg. Amort. 490.735649 102.750444 669.806880 723.163827  53.356947
#
#              ExcessKurtosis
# Bullet             0.236004
# French             0.253306
# Linear             0.108394
# Neg. Amort.        0.184273

# %% [markdown]
# ## Mixed sectors

# %%
rng = np.random.default_rng(1265883927568217)

N_firms = 1000
J = 3

c = 0.01

T = 1.0

NUM_TRIALS = 2500

kappa = rng.uniform(0.5, 1.5, J)
theta = rng.uniform(0.001, 0.051, J)
sigma_inter = rng.uniform(0.0, 0.2, J)
sigma = np.minimum(np.sqrt(2*kappa*theta), sigma_inter)

idio_factor = rng.uniform(0.01, 0.03, N_firms)

feller = (2 * kappa * theta) / (sigma**2)
print("Feller condition (should be >=1):", feller)

W = generate_portfolio_weights(N_firms, J, "mixed", rng=rng)

delta = c * W

lambda_benchmark = np.array([
    lambda_max_generator(1e-4, theta[j], theta[j],
                         sigma[j], kappa[j])
    for j in range(J)
])


params = {
    'Firms': N_firms,
    'Sectors': J,
    'Global Senstivity Param': c,
    'kappa': kappa,
    'theta': theta,
    'sigma': sigma,
    'delta': delta,
    'lambda_benchmark': lambda_benchmark,
    'idio_factor': idio_factor,
    'W': W,
    'T': T
}
# Out:
# Feller condition (should be >=1): [3.637663 4.700201 5.508869]

# %%
loan_b = [
    {
        "type": 'bullet',
        "P": 10.0,
        "N": 12,
        "r": 0.12,
    }
    for i in range(N_firms)
]

losses_b = run_simulation(params, loan_b, num_trials=NUM_TRIALS)
metrics_b = compute_metrics(losses_b, alpha=0.95)
metrics_b_df = pd.DataFrame(metrics_b, index=['Bullet'])
print(metrics_b_df)

loss_distribution_plot(losses_b, 'mixed_bullet')
# Out:
#              Mean        Std        VaR         ES  Excess ES  ExcessKurtosis
# Bullet 539.765275 119.362964 749.724262 811.772138  62.047876        0.282138

# %%
loan_f = [
    {
        "type": 'french',
        "P": 10.0,
        "N": 12,
        "r": 0.12,
    }
    for i in range(N_firms)
]

losses_f = run_simulation(params, loan_f, num_trials=NUM_TRIALS)
metrics_f = compute_metrics(losses_f, alpha=0.95)
metrics_f_df = pd.DataFrame(metrics_f, index=['French'])
print(metrics_f_df)

loss_distribution_plot(losses_f, 'mixed_french')
# Out:
#              Mean       Std        VaR         ES  Excess ES  ExcessKurtosis
# French 222.286553 47.267558 304.874417 326.829726  21.955309        0.135842

# %%
loan_l = [
    {
        "type": 'linear',
        "P": 10.0,
        "N": 12,
        "r": 0.12,
    }
    for i in range(N_firms)
]

losses_l = run_simulation(params, loan_l, num_trials=NUM_TRIALS)
metrics_l = compute_metrics(losses_l, alpha=0.95)
metrics_l_df = pd.DataFrame(metrics_l, index=['Linear'])
print(metrics_l_df)

loss_distribution_plot(losses_l, 'mixed_linear')
# Out:
#              Mean       Std        VaR         ES  Excess ES  ExcessKurtosis
# Linear 216.080282 46.306268 298.659006 320.770658  22.111652        0.262518

# %%
loan_n = [
    {
        "type": 'negative_amortisation',
        "P": 10.0,
        "N": 12,
        "r": 0.12,
    }
    for i in range(N_firms)
]

losses_n = run_simulation(params, loan_n, num_trials=NUM_TRIALS)
metrics_n = compute_metrics(losses_n, alpha=0.95)
metrics_n_df = pd.DataFrame(metrics_n, index=['Neg. Amort.'])
print(metrics_n_df)

loss_distribution_plot(losses_n, 'mixed_neg_amort')
# Out:
#                   Mean        Std        VaR         ES  Excess ES  \
# Neg. Amort. 594.683912 129.787282 817.818310 881.708938  63.890628
#
#              ExcessKurtosis
# Neg. Amort.       -0.012862

# %%
mixedsectors_df = pd.concat([metrics_b_df, metrics_f_df, metrics_l_df, metrics_n_df])
mixedsectors_df
# Out:
#                   Mean        Std        VaR         ES  Excess ES  \
# Bullet      539.765275 119.362964 749.724262 811.772138  62.047876
# French      222.286553  47.267558 304.874417 326.829726  21.955309
# Linear      216.080282  46.306268 298.659006 320.770658  22.111652
# Neg. Amort. 594.683912 129.787282 817.818310 881.708938  63.890628
#
#              ExcessKurtosis
# Bullet             0.282138
# French             0.135842
# Linear             0.262518
# Neg. Amort.       -0.012862

# %%
excess_es_df = pd.DataFrame({
    'Balanced': balancedsectors_df['Excess ES'],
    'Concentrated': concentratedsectors_df['Excess ES'],
    'Mixed': mixedsectors_df['Excess ES']
})

fig, ax = plt.subplots(figsize=(6, 4))
colors = ['#2C3E50', '#C0392B', '#27AE60']
markers = ['o', 's', '^']
for i, col in enumerate(excess_es_df.columns):
    ax.plot(excess_es_df.index, excess_es_df[col], marker=markers[i],
            color=colors[i], linewidth=1.5, markersize=6, label=col)
ax.set_ylabel('Excess ES')
ax.set_xlabel('Loan Type')
ax.legend(frameon=False)
ax.grid(axis='y', linestyle='--', alpha=0.4)
fig.tight_layout()
fig.savefig("../images/schedules_blgd/excess_es_by_loan_type.pdf", format='pdf', dpi=300, bbox_inches='tight')
fig.savefig("../images/schedules_blgd/excess_es_by_loan_type.png", format='png', dpi=300, bbox_inches='tight')
plt.close(fig)

# %%
es_df = pd.DataFrame({
    'Balanced': balancedsectors_df['ES'],
    'Concentrated': concentratedsectors_df['ES'],
    'Mixed': mixedsectors_df['ES']
})

fig, ax = plt.subplots(figsize=(6, 4))
colors = ['#2C3E50', '#C0392B', '#27AE60']
markers = ['o', 's', '^']
for i, col in enumerate(es_df.columns):
    ax.plot(es_df.index, es_df[col], marker=markers[i],
            color=colors[i], linewidth=1.5, markersize=6, label=col)
ax.set_ylabel('Expected Shortfall ($\\mathrm{ES}_{0.95}$)')
ax.set_xlabel('Loan Type')
ax.legend(frameon=False)
ax.grid(axis='y', linestyle='--', alpha=0.4)
fig.tight_layout()
fig.savefig("../images/schedules_blgd/es_by_loan_type.pdf", format='pdf', dpi=300, bbox_inches='tight')
fig.savefig("../images/schedules_blgd/es_by_loan_type.png", format='png', dpi=300, bbox_inches='tight')
plt.close(fig)

# %%
k_df = pd.DataFrame({
    'Balanced': balancedsectors_df['ExcessKurtosis'],
    'Concentrated': concentratedsectors_df['ExcessKurtosis'],
    'Mixed': mixedsectors_df['ExcessKurtosis']
})

fig, ax = plt.subplots(figsize=(6, 4))
colors = ['#2C3E50', '#C0392B', '#27AE60']
markers = ['o', 's', '^']
for i, col in enumerate(k_df.columns):
    ax.plot(k_df.index, k_df[col], marker=markers[i],
            color=colors[i], linewidth=1.5, markersize=6, label=col)
ax.set_ylabel('Excess Kurtosis')
ax.set_xlabel('Loan Type')
ax.legend(frameon=False)
ax.grid(axis='y', linestyle='--', alpha=0.4)
fig.tight_layout()
fig.savefig("../images/schedules_blgd/excess_kurtosis_by_loan_type.pdf", format='pdf', dpi=300, bbox_inches='tight')
fig.savefig("../images/schedules_blgd/excess_kurtosis_by_loan_type.png", format='png', dpi=300, bbox_inches='tight')
plt.close(fig)
